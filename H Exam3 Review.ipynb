# %% [markdown]
# # [CPSC 310](https://github.com/GonzagaCPSC310) Data Mining
# [Gonzaga University](https://www.gonzaga.edu/)
#
# [Gina Sprint](http://cs.gonzaga.edu/faculty/sprint/)
#
# # Exam #3 Review

# %% [markdown]
# ## What to Bring?
# * Two sharp pencils and a good eraser
# * Data mining and Python programming knowledge in your head :)
#
# ## What NOT to Bring?
# * Electronics (including calculators) may not be used during the exam!
# * Notes may not be used during the exam!
#     * You may use your RQ note cards if you turned them in
#
# Note: If you are caught cheating, your exam will be confiscated and you will receive a 0.
#
# Note: Use the restroom before class. Once testing starts, the only reason for leaving the classroom is turning in your exam as done.
#
# ## Exam Format
# The exam will be closed-book, closed-notes (except for RQ notecards), and closed-friends. The exam format is paper pencil and it will have a mix of concept questions and programming questions.
#
# ## Exam Time Frame
# Please be aware that, because you will be taking the exam during a normal lecture period (50 minutes), time will be extremely tight for the exam so work efficiently and manage your time well. If you show up late to class, you will have less time to take the exam.
#
# ## Exam Coverage
# The exam covers everything we have covered so far in the course. Here is a general outline of the topics we have covered so far (note that this list is not comprehensive of everything we have covered so far, but a general outline):
#
# ### U0-3
# See the Exam #1 Review Guide.
#
# ### U4-5
# See the Exam #2 Review Guide.
#
# ### U6 Ensemble Learning (RQ8-Bramer Ch. 14)
# 1. What is ensemble learning and why do we use it?
# 1. Homogeneous vs. heterogeneous ensemble classification
# 1. Examples of generating ensembles for classification
#     1. What are different parameters we can vary?
# 1. What is bagging and why do we use it?
#     1. Know the bagging algorithm
#     1. What is a bootstrap sample and why do we use it?
#     1. What are some advantages of bagging?
# 1. What is a validation set and why do we use it?
# 1. What is a random forest and why do we use it?
#     1. Know how to apply and implement the random forest algorithm we went over in class
#     1. Examples of generating random forests
#     1. What are different parameters we can vary?
#     1. What are N, M, and F?
# 1. How are predictions from multiple learners in an ensemble combined to make a prediction?
# 1. Simple majority voting vs. weighted majority voting vs. track record majority voting
#     1. Know how to apply and implement these voting approaches
#     1. What are issues with simple majority voting?
#     1. How do we overcome these issues? In other words, why do we use weighted and track record voting?
#
# ### U7 Unsupervised Learning (RQ9, 10-Bramer Ch. 16, 17, 19)
# 1. What is unsupervised learning and why do we use it?
#     1. What are examples of unsupervised learning algorithms and applications?
# 1. What is association rule mining (ARM) and why do we use it?
#     1. What is the general form of an ARM rule?
#     1. What is the head of a rule? Body? Consequent? Antecedent?
#     1. How are ARM rules different from classification rules (e.g. decision tree rules)?
#     1. What does it mean to specialize a rule vs. generalize a rule?
#     1. Rules don't imply causality!!
#     1. What is a brute force approach to finding rules?
#         1. What are issues with this approach?
#         1. How do we overcome these issues? E.g. J-Measure and beam search, Apriori, ...
# 1. What are rule interestingness measures and why do we use them?
#     1. What is confidence and why do we use it?
#     1. What is support and why do we use it?
#     1. What is completeness and why do we use it?
# 1. What is market basket analysis (MBA) and why do we use it?
#     1. What is a transaction/itemset and why do we use it?
#     1. What do association rules for itemsets mean?
#     1. What does it mean for an itemset $S$ to "match" a transaction $T$?
#         1. Why are we interested in matches?
#         1. How do you compute count($S$)?
#     1. What is the set $I$ and why do we use it?
#     1. What is support of an itemset and why do we use it?
#     1. What is support of a MBA rule and why do we use it?
#     1. What is confidence of a MBA rule and why do we use it?
#     1. What is $minsup$ and $minconf$ and why do we use them?
#         1. What are common values of these parameters?
# 1. What is the apriori algorithm and why do we use it?
#     1. Know how to apply and implement the apriori algorithm
#     1. What is $L_{k}$ and why do we compute it?
#     1. What is $C_{k}$ and why do we compute it?
#     1. How do we generate rules from supported itemsets?
#     1. What is a trick to speed up rule generation?
#     1. What are apriori rule interestingness measures?
#         1. What is leverage and why do we use it?
#         1. What is lift and why do we use it?
# 1. Basics of set theory
#     1. Be familiar with the following terms and in many cases, how to compute them: set, subset, superset, power set, empty set, union of sets, intersection of sets, etc.
#     1. How to represent a set in Python?
# 1. What is k-means clustering and why do we use it?
#     1. Know how to apply and implement the k-Means clustering algorithm
#     1. What is a centroid and why do we use it?
#     1. How do we determine distance between a pair of clusters?
#     1. How do measure cluster quality and why?
#     1. How can determine "good" values of k?
# 1. What is hierarchical clustering and why do we use it?
# 1. What is a dendogram and why do we use it?
# 1. Extra topics (will not be tested via programming questions, but are fair game for conceptual questions)
#     1. The Python data science ecosystem, e.g. numpy, scipy, pandas, etc.
#     1. Pandas series vs. dataframe
#     1. Running Jupyter Notebooks in the cloud via Amazon SageMaker

# %% [markdown]
# # Recommended Strategy for Preparing for the Exam
# The exam questions will require you to solve problems in a variety of formats: defining key terms/concepts, applying algorithms to example datasets, writing code, determining the output of code, etc.
#
# I recommend that you use the following activities and materials to prepare for the exam:
# * Review reading quizzes, warm-up tasks, programming assignments, problems solved in class, and code derived in class
#     * These may well be your best resources
#     * An excellent learning activity would be to re-solve these exercises
# * Lesson notes
# * Re-read the pages assigned for the reading quizzes
#     * Solve the problems included at the end of the chapters
#
# ## Extra Practice Problems
# ### 1
# Consider the following dataset.
#
# |att1|att2|att3|
# |-|-|-|
# |1|5|yes|
# |1|6|yes|
# |2|5|no|
# |2|5|no|
# |1|6|yes|
# |2|6|no|
# |1|5|yes|
# |1|6|yes|
# |2|5|no|
# |1|6|yes|
#
# Calculate the following metrics for the given rule: RULE:  IF att3==yes THEN att2==6 && att1==1
# 1. $N_{left}$ =
# 1. $N_{right}$ =
# 1. $N_{both}$ =
# 1. $N_{total}$ =
# 1. support =
# 1. confidence =
# 1. completeness =
#
# ### 2
# Assume att1's domain is {1, 2}, att2's domain is {5, 6}, and att3's domain is {yes, no}. If we want to generate all possible RHSs of rules (of any appropriate length for a rule), what is the maximum number of RHSs we would need based on the domain values? Show your work.
#
# ### 3
# Complete the problems from Bramer Self-assessment Exercises: 2.8, 3.6, 4.5, 5.5, 7.9, 12.8 (we didn't cover ROC graphs but you can still answer most of this question), 14.8, 16.6, 17.11, 19.5
#
# ### 4
# Consider the following set of transactions:
#
# |transaction|itemset|
# |-|-|
# |1|{b,c,m}|
# |2|{b,c,e,m,s}|
# |3|{b}|
# |4|{c,e,s}|
# |5|{c}|
# |6|{b,c,s}|
# |7|{c,e,s}|
# |8|{c,e}|
# |9|{b,c}|
# |10|{b,c,e,s}|
#
# 1. Calculate the following metrics for the rule: IF {b,c} THEN {s}.
#     1. Support =
#     1. Confidence =
#     1. Lift =
# 1. Assume `minsup` is set at 40%. List all of the itemsets in $L_2$ (where $L_2$ is generated from the Apriori algorithm).
#
# ### 5
# Re-solve the labs we went over together in class: Majority Voting Lab, Intro to Association Rule Mining Lab, and Apriori Lab.
#
# ### 6
# For the following questions, use the iPhone Purchases (Fake) dataset:
#
# |standing |job_status |credit_rating |buys_iphone|
# |-|-|-|-|
# |1 |3 |fair |no|
# |1 |3 |excellent |no|
# |2 |3 |fair |yes|
# |2 |2 |fair |yes|
# |2 |1 |fair |yes|
# |2 |1 |excellent |no|
# |2 |1 |excellent |yes|
# |1 |2 |fair |no|
# |1 |1 |fair |yes|
# |2 |2 |fair |yes|
# |1 |2 |excellent |yes|
# |2 |2 |excellent |yes|
# |2 |3 |fair |yes|
# |2 |2 |excellent |no|
# |2 |3 |fair |yes|
#
# 1. Give an example of a complete decision tree that could be generated using the random forest approach
# 1. Show the random attribute subset for each attribute node in the tree.
#
# <img src="https://s3-ap-south-1.amazonaws.com/av-blog-media/wp-content/uploads/2017/02/12152925/meme.jpg" width="300"/>
#
# ### 7
# The following questions refer to the buys iphone dataset from class.
#
# |standing |job_status |credit_rating |buys_iphone|
# |-|-|-|-|
# |1 |3 |fair |no|
# |1 |3 |excellent |no|
# |2 |3 |fair |yes|
# |2 |2 |fair |yes|
# |2 |1 |fair |yes|
# |2 |1 |excellent |no|
# |2 |1 |excellent |yes|
# |1 |2 |fair |no|
# |1 |1 |fair |yes|
# |2 |2 |fair |yes|
# |1 |2 |excellent |yes|
# |2 |2 |excellent |yes|
# |2 |3 |fair |yes|
# |2 |2 |excellent |no|
# |2 |3 |fair |yes|
#
# Using all the attributes except the class (buys iphone), *show the first iteration* of k-means clustering with k=2. Use the first and last instances as initial centroids. Note: You'll need to convert credit_rating to a numeric attribute or use an Euclidean distance adapted for categorical attributes.
#
#
#
# ### 8
# This problem is adapted from [this site](https://www.saedsayad.com/clustering_kmeans.htm).
#
# Suppose we want to group the visitors to a website using just their age (one-dimensional space) as follows (n = 19): 15,15,16,19,19,20,20,21,22,28,35,40,41,42,43,44,60,61,65
#
# 1. Using k-means clustering with k = 2 and initial centroids of $c_{1}$ = 16 and $c_{2}$ = 22, compute the two clusters.
# 1. What is the total sum of squares (TSS) of each of the clusters?
#
# <img src="https://memegenerator.net/img/instances/45445872.jpg" width="300"/>
#
# Nice work on making it through the practice problems!! Do well on the exam!!
